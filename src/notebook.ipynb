# %%
# Usage example

from Util.textExtractor import DocumentTextExtractor


extractor = DocumentTextExtractor()

# Single file extraction
text = extractor.extract_text("B015_AkanshiJain.pptx")
print(text)
# Out:
# PowerPoint Presentation
#
# WIZ Product Case Study
# You have been on-boarded as a Product Manager for Instagram. In your monthly catchup meeting, you found that businesses or brands are paying influencers for posting adverts on their profile. Influencers are also generating decent revenue out of their followers, but there is no feature that caters to this use case & the entire process happens over DMs/outside the platform.
# Name:- Akanshi Jain
# Roll No:- B015
# Department:- Centre of Excellence , NMIMS
#
#
# DESCRIPTION OF THE FEATURE
#
# LOGO
# This feature will help the brands to find top  influencers which will be perfect for their advertisements and further collaborate with them
# Name of the feature:- Focus
#
# ...

# %%
# Multiple file extraction
files = ["path/to/file1.pdf", "path/to/file2.jpg", "path/to/file3.pptx"]
combined_text = extractor.extract_text_from_multiple_files(files)
print(combined_text)
